# %%
import twint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nest_asyncio
import re
#from textblob import TextBlob
#from nltk.tokenize import WordPunctTokenizer
#from nltk.corpus import stopwords   
from datetime import datetime
import glob                     
import os
nest_asyncio.apply()

# %%
name={'Zarr':'#zarr'
    }

# %%
def twintConfig(search_string):
    c = twint.Config()
    c.Search = search_string[1]
    c.Limit=500
    c.Lang = 'en'
    c.Pandas = True
    c.Pandas_au = True          
    c.Pandas_clean=True
    c.Since='2016-01-01'
    c.Until='2022-12-31'
    twint.run.Search(c)

# %%
def Run_Twint(search_vals):
    
    #set empty dataframe for join
    out_df= pd.DataFrame()
    
    for zarr in search_vals.items():
        print ("running for search item: "+zarr[0]+"\n")
        print ("Search string: "+zarr[1]+"\n")
        
        #run twint
        twintConfig(zarr)
        
        #get dataframe
        tweets_df = twint.storage.panda.Tweets_df
        
        #join Dataframes and create 'Candi' column
        tweets_df["Zarr_tweet"]= zarr[0]
        out_df = pd.concat([out_df,tweets_df])
        
    return out_df

# %%
twint_df = Run_Twint(name)
# Out:
# running for search item: Zarr
#
# Search string: #zarr
#
# 1587745091040563201 2022-11-02 10:55:03 +0100 <zarr_dev> 🎞️ Looking for videos about #Zarr?  Finding some just got easier ▶️  https://t.co/T8jVwMHemq
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %%
tweets_df
# Out:
#                      id      conversation_id    created_at  \
# 0   1209664384449961984  1209664384449961984  1.577241e+12
# 1   1207352060053741569  1207343263805517826  1.576690e+12
# 2   1204841202459144197  1204841202459144197  1.576092e+12
# 3   1197567468845309952  1197567468845309952  1.574357e+12
# 4   1195287464707022848  1195287464707022848  1.573814e+12
# 5   1195039103441616896  1195039103441616896  1.573754e+12
# 6   1195031794623664129  1195031794623664129  1.573753e+12
# 7   1194742247079546881  1194396293935882242  1.573684e+12
# 8   1188414297816231937  1188414095856300032  1.572175e+12
# 9   1188045023503241216  1188044963864440832  1.572087e+12
# 10  1183830931179790340  1183830931179790340  1.571082e+12
# 11  1182352773813362688  1182211672989208578  1.570730e+12
# 12  1176921191983931398  1176921191983931398  1.569435e+12
# 13  1176682762616655872  1176682762616655872  1.569378e+12
# 14  1174706061879603201  1174706061879603201  1.568907e+12
# ...

# %%
tweets_df.columns
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'timezone', 'place',
#        'tweet', 'language', 'hashtags', 'cashtags', 'user_id', 'user_id_str',
#        'username', 'name', 'day', 'hour', 'link', 'urls', 'photos', 'video',
#        'thumbnail', 'retweet', 'nlikes', 'nreplies', 'nretweets', 'quote_url',
#        'search', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest', 'Zarr_tweet'],
#       dtype='object')

# %%
pd.set_option('display.max_colwidth', None)

# %%
tweets_df[['tweet', 'link','language']].iloc[21:31]
# Out:
#                                                                                                                                                                                                                                                                         tweet  \
# 21                                        @mdsumner @TimSalabim3 @gdkrmr For #lexube not, but the suggestion by @TimSalabim3 was to do it with R. Considering that most #DataCube data coma as #zarr that is not really efficient right now and would require some detours...
# 22                                       @TimSalabim3 Would be really great, but to the best of our knowledge there is still no #rstats #zarr package available that makes that possible... or have there been some developments we missed @gdkrmr ?  https://t.co/KCmsTzyDQe
# ...

# %%
df=pd.read_csv('zarr_tweets.csv')
df
# Out:
#                      id      conversation_id  \
# 0   1587745091040563201  1587745091040563201
# 1   1585280372698484736  1585280372698484736
# 2   1582413612433346571  1582413612433346571
# 3   1580130892692918272  1580130892692918272
# 4   1574417198495449092  1574417198495449092
# 5   1574409561024380930  1574409561024380930
# 6   1574097650047229954  1574097616987688963
# 7   1574097645806682121  1574097616987688963
# 8   1573183377812889600  1573183377812889600
# 9   1573036727169871872  1573036727169871872
# 10  1572981355180433408  1572677162045407233
# 11  1572228320745623552  1572228320745623552
# 12  1571895741647388674  1571895741647388674
# 13  1570064709306679298  1570060307044929536
# 14  1570060307044929536  1570060307044929536
# 15  1568203759855058945  1568203736568238080
# 16  1567577711006056455  1567577711006056455
# 17  1565708621303885824  1565708621303885824
# 18  1564289274555469824  1564289274555469824
# 19  1562141195593302017  1562141195593302017
# ...

# %%
df.columns
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'time', 'timezone',
#        'user_id', 'username', 'name', 'place', 'tweet', 'language', 'mentions',
#        'urls', 'photos', 'replies_count', 'retweets_count', 'likes_count',
#        'hashtags', 'cashtags', 'link', 'retweet', 'quote_url', 'video',
#        'thumbnail', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest'],
#       dtype='object')

# %%
df[['username', 'tweet', 'tweet']]
# Out:
#            username  \
# 0          zarr_dev
# 1          remitano
# 2    openmicroscopy
# 3      ruth_mottram
# 4         cschrader
# 5            azavea
# 6          rajadain
# 7          rajadain
# 8    it4innovations
# 9            azavea
# 10  philippbauman15
# 11      msankeys963
# 12         zarr_dev
# 13          incforg
# 14          incforg
# 15         zarr_dev
# 16        ironarray
# 17         tswetnam
# 18         3x0narts
# 19  satyakomatineni
# 20         3x0narts
# 21   migueldmahecha
# 22   migueldmahecha
# 23   eurobioimaging
# 24         zarr_dev
# 25          zaar_88
# 26  abidjankhattak3
# 27     latlong_blog
# 28      pydatadelhi
# 29     ulrike_boehm
# 30     notjustmoore
# 31        ironarray
# 32         zarr_dev
# 33           giswqs
# 34  geosolutions_it
# 35  glencoesoftware
# 36         3x0narts
# 37    clintcabanero
# 38  glencoesoftware
# 39   alexanderrey42
# 40       sourcepole
# 41  ourradiantearth
# 42         mdsumner
# 43  ourradiantearth
# ...

# %%
concat_df = pd.concat([tweets_df, df], axis=0)

# %%
concat_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 concat_df
#
# NameError: name 'concat_df' is not defined

# %%
concat_df.to_csv('concat_df.csv')

# %%
# create dataframe
data = pd.DataFrame({'name': ['sireesha', 'priyank',
                                  'ojaswi', 'gnanesh'],
                         'subjects': ['java', 'networks',
                                      'c', 'c#']})
  
# consider a list
list1 = ['sireesha', 'priyank']
  
# check the pandas name column
# contain the given list if strings
#print(data[data['name'].isin(list1)])
  
# consider a list
list2 = ['java', 'c']
  
# check the pandas subjects column
# contain the given list if strings
data[~data['subjects'].isin(list2)]
# Out:
#       name  subjects
# 1  priyank  networks
# 3  gnanesh        c#

# %%
df = pd.read_csv('concat_df.csv')
df.head()
# Out:
#    Unnamed: 0                   id      conversation_id       created_at  \
# 0           0  1209664384449961984  1209664384449961984  1577241438000.0
# 1           1  1207352060053741569  1207343263805517826  1576690137000.0
# 2           2  1204841202459144197  1204841202459144197  1576091502000.0
# 3           3  1197567468845309952  1197567468845309952  1574357308000.0
# 4           4  1195287464707022848  1195287464707022848  1573813713000.0
#
#                   date  timezone  place  \
# 0  2019-12-25 03:37:18       100    NaN
# 1  2019-12-18 18:28:57       100    NaN
# 2  2019-12-11 20:11:42       100    NaN
# 3  2019-11-21 18:28:28       100    NaN
# 4  2019-11-15 11:28:33       100    NaN
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'conversation_id', 'created_at', 'date', 'timezone',
#        'place', 'tweet', 'language', 'hashtags', 'cashtags', 'user_id',
#        'user_id_str', 'username', 'name', 'day', 'hour', 'link', 'urls',
#        'photos', 'video', 'thumbnail', 'retweet', 'nlikes', 'nreplies',
#        'nretweets', 'quote_url', 'search', 'near', 'geo', 'source',
#        'user_rt_id', 'user_rt', 'retweet_id', 'reply_to', 'retweet_date',
#        'translate', 'trans_src', 'trans_dest', 'Zarr_tweet', 'time',
#        'mentions', 'replies_count', 'retweets_count', 'likes_count'],
#       dtype='object')

# %%
df2 = df[['date', 'username', 'tweet', 'link', 'language']]
df2
# Out:
#                     date         username  \
# 0    2019-12-25 03:37:18        75Hexagon
# 1    2019-12-18 18:28:57       Julien_Lau
# 2    2019-12-11 20:11:42       edhartnett
# 3    2019-11-21 18:28:28     pleiszenburg
# 4    2019-11-15 11:28:33         zarr_dev
# ..                   ...              ...
# 101           2022-02-28  ourradiantearth
# 102           2022-02-24         mdsumner
# 103           2022-02-23  ourradiantearth
# 104           2022-02-09  glencoesoftware
# 105           2022-01-19         jimmyc42
#
#                                                                                                                                                                                                                                                                                                                  tweet  \
# ...

# %%
tweets=['https://twitter.com/geosolutions_it/status/1516167576581255168', 
        'https://twitter.com/PyDataDelhi/status/1528047388627456000', 
        'https://twitter.com/opengeospatial/status/1415692393068867595', 
        'https://twitter.com/Ulrike_Boehm/status/1526977063067983872', 
        'https://twitter.com/pleiszenburg/status/1254786742126690306',
        'https://twitter.com/higlass_io/status/1292947250935554049',
        'https://twitter.com/BrockmannCon/status/1324293687812173824',
        'https://twitter.com/_jhamman/status/1233416097388326912',
        'https://twitter.com/Underfox3/status/1559312865269530626', 
        'https://twitter.com/carbonplanorg/status/1442559371775397889', 
        'https://twitter.com/LLC4320Bot/status/1274862822778982402', 
        'https://twitter.com/trevmanz/status/1265377097981329423', 
        'https://twitter.com/rajadain/status/1574097641469841410', 
        'https://twitter.com/notjustmoore/status/1579536653852766208', 
        'https://twitter.com/azavea/status/1573036727169871872', 
        'https://twitter.com/notjustmoore/status/1256232842755014656', 
        'https://twitter.com/rajadain/status/1574097638747537408', 
        'https://twitter.com/latlong_blog/status/1543726888908009472', 
        'https://twitter.com/openmicroscopy/status/1582413612433346571', 
        'https://twitter.com/rajadain/status/1574097645806682121',
        'https://twitter.com/latlong_blog/status/1543726888908009472',
        'https://twitter.com/ruth_mottram/status/1580130892692918272', 
        'https://twitter.com/ngehlenborg/status/1369316956956995588', 
        'https://twitter.com/Ulrike_Boehm/status/1526977063067983872', 
        'https://twitter.com/pleiszenburg/status/1197567468845309952', 
        'https://twitter.com/latlong_blog/status/1543726888908009472', 
        'https://twitter.com/_jhamman/status/1579882167303168004', 
        'https://twitter.com/ErikvanSebille/status/1578030942144188417', 
        'https://twitter.com/opencholmes/status/1583130100756643845', 
        'https://twitter.com/notjustmoore/status/1256232842755014656', 
        'https://twitter.com/LLC4320Bot/status/1274862822778982402', 
        'https://twitter.com/azavea/status/1573036727169871872', 
        'https://twitter.com/rabernat/status/1573103573373943810', 
        'https://twitter.com/maximlamare/status/1430805616273108995', 
        'https://twitter.com/tswetnam/status/1565708621303885824', 
        'https://twitter.com/latlong_blog/status/1543726888908009472', 
        'https://twitter.com/GdalOrg/status/1417318103491416064', 
        'https://twitter.com/azavea/status/1573036727169871872', 
        'https://twitter.com/IT4Innovations/status/1573183377812889600', 
        'https://twitter.com/al_merose/status/1582792311963934720', 
        'https://twitter.com/herrsaalfeld/status/1176682762616655872', 
        'https://twitter.com/VortexFdC/status/1434952297126170624', 
        'https://twitter.com/ngehlenborg/status/1369316956956995588', 
        'https://twitter.com/googleai/status/1573064656914190337']

# %%
df2 = df2[~(df2['link'].isin(tweets))]

# %%
df2[df2.duplicated()]
# Out:
# Empty DataFrame
# Columns: [date, username, tweet, link, language]
# Index: []

# %%
#droping rows which languange =! english
df2 = df2[df2["language"].isin(['en'])]

# %%
subset=['onthewatah', 'ZarrmageddonTRG', 'thebabybadass', 'AmeristarVI', 'kleighjack', 'juu_naaa', 'Vile_Nkosi', 
        'Travelers365', 'Jiyaseher1', 'LifeofRio', 'a_nameless1', 'Al9rayed', 'DoubleQuicktime', 'FunnyTshirts101', 
       'MinieHouselook', 'MassachusettsL1', 'buttlm', 'remitano', 'msankeys963', 'zarr_dev', 'notjustmoore', '3x0narts']
df2 = df2[~(df2['username'].isin(subset))].reset_index(drop=True)

# %%
#df2 = df2.reset_index(drop=True)
df2
# Out:
#                    date         username  \
# 0   2019-12-18 18:28:57       Julien_Lau
# 1   2019-12-11 20:11:42       edhartnett
# 2   2019-11-14 19:01:39         NumFOCUS
# 3   2019-11-14 18:32:37         NumFOCUS
# 4   2019-11-13 23:22:03       loicaroyer
# 5   2019-10-10 18:50:42         _jhamman
# 6   2019-09-19 16:25:24  Kimberl64788230
# 7   2019-07-26 14:31:48    TobiasAdeJong
# 8   2019-07-10 20:34:27         eramirem
# 9   2019-07-02 02:07:27           shoyer
# 10  2019-06-17 20:34:23         _jhamman
# 11  2019-05-17 02:57:44    JuliusBusecke
# 12  2018-12-12 23:39:58         _jhamman
# 13  2018-03-29 10:03:54      andreazonca
# 14  2017-08-24 20:59:00         ijstokes
# 15  2016-09-13 19:38:33    FrancescAlted
# 16  2016-04-15 16:14:39    FrancescAlted
# 17           2022-09-26        cschrader
# 18           2022-09-26           azavea
# 19           2022-09-25         rajadain
# 20           2022-09-22  philippbauman15
# 21           2022-09-14          incforg
# ...

# %%
for x in df2['link']:
    print(x)
# Out:
# https://twitter.com/Julien_Lau/status/1207352060053741569
# https://twitter.com/edhartnett/status/1204841202459144197
# https://twitter.com/NumFOCUS/status/1195039103441616896
# https://twitter.com/NumFOCUS/status/1195031794623664129
# https://twitter.com/loicaroyer/status/1194742247079546881
# https://twitter.com/_jhamman/status/1182352773813362688
# https://twitter.com/Kimberl64788230/status/1174706061879603201
# https://twitter.com/TobiasAdeJong/status/1154746138869846016
# https://twitter.com/eramirem/status/1149039195740131329
# https://twitter.com/shoyer/status/1145861508460498944
# https://twitter.com/_jhamman/status/1140704257961652224
# https://twitter.com/JuliusBusecke/status/1129204320518451200
# https://twitter.com/_jhamman/status/1072984431814684673
# https://twitter.com/andreazonca/status/979282994816012288
# https://twitter.com/ijstokes/status/900809689025437697
# https://twitter.com/FrancescAlted/status/775765627826950144
# ...
